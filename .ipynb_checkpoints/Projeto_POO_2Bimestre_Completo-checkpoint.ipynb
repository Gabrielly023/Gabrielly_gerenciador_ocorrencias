# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** **Gabrielly Gonçalves**
#
# **Turma:** **2°A-TI**
#
# **Tema Escolhido:** **Crie um sistema que registre ocorrências escolares**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
class OcorrenciaEscolar_gabrielly:
    def __init__(self, aluno, data, descricao):
        self.aluno = aluno            
        self.data = data              
        self.descricao = descricao    

    def exibir_ocorrencia_gabrielly(self):
        print(f"Aluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self.descricao}")

ocorrencia1 = OcorrenciaEscolar_gabrielly("João Silva", "08/05/2025", "Chegou atrasado pela terceira vez na semana.")
ocorrencia2 = OcorrenciaEscolar_gabrielly("Maria Oliveira", "07/05/2025", "Foi flagrada utilizando o celular durante a aula.")

ocorrencia1.exibir_dados()
ocorrencia2.exibir_dados()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class OcorrenciaEscolar_gabrielly:
    def __init__(self, aluno, data, descricao):
        self.aluno = aluno            
        self.data = data              
        self.descricao = descricao    

    def exibir_ocorrencia_gabrielly(self):
        print(f"Aluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self.descricao}")

    def atualizar_descricao(self, nova_descricao):
        self.descricao = nova_descricao
        print("Descrição atualizada com sucesso!")

    def alterar_data(self, nova_data):
        self.data = nova_data
        print("Data da ocorrência alterada com sucesso!")

class OcorrenciaGrave(OcorrenciaEscolar_gabrielly):
    def __init__(self, aluno, data, descricao, nivel_gravidade):
        super().__init__(aluno, data, descricao) 
        self.nivel_gravidade = nivel_gravidade    

    def exibir_alerta(self):
        print("⚠️ ALERTA DE OCORRÊNCIA GRAVE ⚠️")
        self.exibir_ocorrencia_gabrielly()
        print(f"Nível de Gravidade: {self.nivel_gravidade}")

ocorrencia1 = OcorrenciaEscolar_gabrielly("João Silva", "08/05/2025", "Chegou atrasado pela terceira vez na semana.")
ocorrencia2 = OcorrenciaEscolar_gabrielly("Maria Oliveira", "07/05/2025", "Foi flagrada utilizando o celular durante a aula.")

ocorrencia1.exibir_ocorrencia_gabrielly()
ocorrencia1.atualizar_descricao("Chegou atrasado e sem uniforme.")
ocorrencia1.alterar_data("09/05/2025")
ocorrencia1.exibir_ocorrencia_gabrielly()

ocorrencia_grave = OcorrenciaGrave("Lucas Pereira", "06/05/2025", "Agressão física a outro aluno.", "Alta")
ocorrencia_grave.exibir_alerta()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3 
class OcorrenciaEscolar_gabrielly:
    def __init__(self, aluno, data, descricao):
        self.aluno = aluno            
        self.data = data              
        self.__descricao = descricao 

    def exibir_ocorrencia_gabrielly(self):
        print(f"\nAluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self.__descricao}")

    def get_descricao(self):
        return self.__descricao

    def set_descricao(self, nova_descricao):
        self.__descricao = nova_descricao
        print("Descrição atualizada com sucesso!")

    def atualizar_descricao(self, nova_descricao):
        self.set_descricao(nova_descricao)

    def alterar_data(self, nova_data):
        self.data = nova_data
        print("Data da ocorrência alterada com sucesso!")

    def verificar_reincidencia(self):
        palavras_chave = ["segunda vez", "terceira vez", "reincidente"]
        descricao_lower = self.__descricao.lower()
        for palavra in palavras_chave:
            if palavra in descricao_lower:
                print("⚠️ Aluno reincidente em comportamento inadequado.")
                return True
        print("Sem sinais de reincidência registrados.")
        return False


class OcorrenciaGrave(OcorrenciaEscolar_gabrielly):
    def __init__(self, aluno, data, descricao, nivel_gravidade):
        super().__init__(aluno, data, descricao)
        self.__nivel_gravidade = nivel_gravidade

    def get_nivel_gravidade(self):
        return self.__nivel_gravidade

    def set_nivel_gravidade(self, novo_nivel):
        self.__nivel_gravidade = novo_nivel
        print("Nível de gravidade atualizado com sucesso!")

    def exibir_alerta(self):
        print("\n⚠️ ALERTA DE OCORRÊNCIA GRAVE ⚠️")
        self.exibir_ocorrencia_gabrielly()
        print(f"Nível de Gravidade: {self.__nivel_gravidade}")


while True:
    print("\n=== Registro de Ocorrência ===")

    aluno = input("Nome do aluno: ")
    data = input("Data da ocorrência (dd/mm/aaaa): ")
    descricao = input("Descrição da ocorrência: ")
    tipo = input("A ocorrência é grave? (s/n): ").strip().lower()

    if tipo == 's':
        nivel = input("Nível de gravidade (Alta/Média/Baixa): ")
        ocorrencia = OcorrenciaGrave(aluno, data, descricao, nivel)
        ocorrencia.exibir_alerta()
    else:
        ocorrencia = OcorrenciaEscolar_gabrielly(aluno, data, descricao)
        ocorrencia.exibir_ocorrencia_gabrielly()

    ocorrencia.verificar_reincidencia()

    atualizar_desc = input("\nDeseja atualizar a descrição? (s/n): ").strip().lower()
    if atualizar_desc == 's':
        nova_desc = input("Digite a nova descrição: ")
        ocorrencia.atualizar_descricao(nova_desc)

    atualizar_data = input("Deseja alterar a data? (s/n): ").strip().lower()
    if atualizar_data == 's':
        nova_data = input("Digite a nova data (dd/mm/aaaa): ")
        ocorrencia.alterar_data(nova_data)

    if tipo == 's':
        ocorrencia.exibir_alerta()
    else:
        ocorrencia.exibir_ocorrencia_gabrielly()

    continuar = input("\nDeseja registrar outra ocorrência? (s/n): ").strip().lower()
    if continuar != 's':
        print("\nEncerrando o sistema de ocorrências.")
        break

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
from datetime import datetime
import mysql.connector

def conectar_banco():
    try:
        
        conexao = mysql.connector.connect(
            host="localhost",
            user="root",
            password="",
            database="registro_ocorrencias"
        )
        print("Conexão com o banco de dados estabelecida com sucesso.")
        return conexao
    except mysql.connector.Error as err:
        print(f"Erro ao conectar ao banco de dados: {err}")
        return None

class OcorrenciaEscolar_gabrielly:
    def __init__(self, aluno, data, descricao):
        self.aluno = aluno
        self.data = data
        self.__descricao = descricao
        self.id = None  

    def exibir_ocorrencia_gabrielly(self):
        print(f"\nAluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self.__descricao}")

    def get_descricao(self):
        return self.__descricao

    def set_descricao(self, nova_descricao):
        self.__descricao = nova_descricao
        print("Descrição atualizada com sucesso!")

    def atualizar_descricao(self, nova_descricao):
        self.set_descricao(nova_descricao)

    def alterar_data(self, nova_data):
        self.data = nova_data
        print("Data da ocorrência alterada com sucesso!")

    def verificar_reincidencia(self):
        palavras_chave = ["segunda vez", "terceira vez", "reincidente"]
        descricao_lower = self.__descricao.lower()
        for palavra in palavras_chave:
            if palavra in descricao_lower:
                print("⚠️ Aluno reincidente em comportamento inadequado.")
                return True
        print("Sem sinais de reincidência registrados.")
        return False

    def salvar_no_banco(self, conexao):
        try:
            cursor = conexao.cursor()
            query = """
                INSERT INTO ocorrencias (aluno, data, descricao, tipo)
                VALUES (%s, %s, %s, %s)
            """
            cursor.execute(query, (
                self.aluno,
                datetime.strptime(self.data, "%d/%m/%Y").date(),
                self.get_descricao(),
                'simples'
            ))
            conexao.commit()
            self.id = cursor.lastrowid  
            print("✅ Ocorrência simples registrada no banco de dados.")
        except mysql.connector.Error as err:
            print(f"Erro ao registrar ocorrência: {err}")
        finally:
            cursor.close()

    
    def excluir_no_banco(self, conexao):
        try:
            if self.id is None:
                print("Erro: ID da ocorrência não encontrado.")
                return
            cursor = conexao.cursor()
            query = "DELETE FROM ocorrencias WHERE id = %s"
            cursor.execute(query, (self.id,))
            conexao.commit()
            print(f"✅ Ocorrência com ID {self.id} excluída com sucesso.")
        except mysql.connector.Error as err:
            print(f"Erro ao excluir ocorrência: {err}")
        finally:
            cursor.close()


class OcorrenciaGrave(OcorrenciaEscolar_gabrielly):
    def __init__(self, aluno, data, descricao, nivel_gravidade):
        super().__init__(aluno, data, descricao)
        self.__nivel_gravidade = nivel_gravidade

    def get_nivel_gravidade(self):
        return self.__nivel_gravidade

    def set_nivel_gravidade(self, novo_nivel):
        self.__nivel_gravidade = novo_nivel
        print("Nível de gravidade atualizado com sucesso!")

    def exibir_ocorrencia_gabrielly(self):
        print("\n⚠️ ALERTA DE OCORRÊNCIA GRAVE ⚠️")
        print(f"Aluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self.get_descricao()}")
        print(f"Nível de Gravidade: {self.__nivel_gravidade}")

    def salvar_no_banco(self, conexao):
        try:
            cursor = conexao.cursor()

        
            query_ocorrencia = """
                INSERT INTO ocorrencias (aluno, data, descricao, tipo)
                VALUES (%s, %s, %s, %s)
            """
            cursor.execute(query_ocorrencia, (
                self.aluno,
                datetime.strptime(self.data, "%d/%m/%Y").date(),
                self.get_descricao(),
                'grave'
            ))
            conexao.commit()
            self.id = cursor.lastrowid  

           
            query_grave = """
                INSERT INTO ocorrencias_graves (id, nivel_gravidade)
                VALUES (%s, %s)
            """
            cursor.execute(query_grave, (self.id, self.__nivel_gravidade))
            conexao.commit()

            print("✅ Ocorrência grave registrada no banco de dados.")
        except mysql.connector.Error as err:
            print(f"Erro ao registrar ocorrência grave: {err}")
        finally:
            cursor.close()


def rodar_sistema():
    conexao = conectar_banco()
    if not conexao:
        print("Não foi possível conectar ao banco de dados. Sistema encerrado.")
        return

    while True:
        print("\n=== Registro de Ocorrência ===")

        aluno = input("Nome do aluno: ")
        data = input("Data da ocorrência (dd/mm/aaaa): ")
        descricao = input("Descrição da ocorrência: ")
        tipo = input("A ocorrência é grave? (s/n): ").strip().lower()

        if tipo == 's':
            nivel = input("Nível de gravidade (Alta/Média/Baixa): ")
            ocorrencia = OcorrenciaGrave(aluno, data, descricao, nivel)
        else:
            ocorrencia = OcorrenciaEscolar_gabrielly(aluno, data, descricao)

        ocorrencia.exibir_ocorrencia_gabrielly()
        ocorrencia.verificar_reincidencia()

        atualizar_desc = input("\nDeseja atualizar a descrição? (s/n): ").strip().lower()
        if atualizar_desc == 's':
            nova_desc = input("Digite a nova descrição: ")
            ocorrencia.atualizar_descricao(nova_desc)

        atualizar_data = input("Deseja alterar a data? (s/n): ").strip().lower()
        if atualizar_data == 's':
            nova_data = input("Digite a nova data (dd/mm/aaaa): ")
            ocorrencia.alterar_data(nova_data)

        ocorrencia.exibir_ocorrencia_gabrielly()

        
        ocorrencia.salvar_no_banco(conexao)

      
        excluir = input("\nDeseja excluir esta ocorrência? (s/n): ").strip().lower()
        if excluir == 's':
            ocorrencia.excluir_no_banco(conexao)

        continuar = input("\nDeseja registrar outra ocorrência? (s/n): ").strip().lower()
        if continuar != 's':
            print("\nEncerrando o sistema de ocorrências.")
            break

    conexao.close()

rodar_sistema()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importa a classe datetime para manipulação de datas
from datetime import datetime

# Importa o módulo mysql.connector para conectar ao banco de dados MySQL
import mysql.connector

# Função que realiza a conexão com o banco de dados
def conectar_banco():
    try:
        # Estabelece conexão com o banco de dados MySQL local
        conexao = mysql.connector.connect(
            host="localhost",       # Endereço do servidor do banco
            user="root",            # Nome de usuário do banco
            password="",            # Senha do banco (vazia aqui)
            database="registro_ocorrencias"  # Nome do banco de dados
        )
        print("Conexão com o banco de dados estabelecida com sucesso.")
        return conexao  # Retorna o objeto de conexão
    except mysql.connector.Error as err:
        # Em caso de erro, exibe a mensagem e retorna None
        print(f"Erro ao conectar ao banco de dados: {err}")
        return None

# Classe base para representar ocorrências escolares simples
class OcorrenciaEscolar:
    def __init__(self, aluno, data, descricao):
        self.aluno = aluno            # Nome do aluno
        self.data = data              # Data da ocorrência
        self._descricao = descricao   # Descrição da ocorrência (privada)
        self.id = None                # ID da ocorrência no banco (definido após salvar)

    # Método para exibir os dados da ocorrência
    def exibir_ocorrencia(self):
        print(f"\nAluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self._descricao}")

    # Método getter para a descrição
    def get_descricao(self):
        return self._descricao

    # Método setter para atualizar a descrição
    def set_descricao(self, nova_descricao):
        self._descricao = nova_descricao
        print("Descrição atualizada com sucesso!")

    # Atualiza a descrição usando o setter
    def atualizar_descricao(self, nova_descricao):
        self.set_descricao(nova_descricao)

    # Altera a data da ocorrência
    def alterar_data(self, nova_data):
        self.data = nova_data
        print("Data da ocorrência alterada com sucesso!")

    # Verifica se há reincidência na descrição da ocorrência
    def verificar_reincidencia(self):
        palavras_chave = ["segunda vez", "terceira vez", "reincidente"]
        descricao_lower = self._descricao.lower()
        for palavra in palavras_chave:
            if palavra in descricao_lower:
                print("⚠️ Aluno reincidente em comportamento inadequado.")
                return True
        print("Sem sinais de reincidência registrados.")
        return False

    # Salva a ocorrência no banco de dados
    def salvar_no_banco(self, conexao):
        try:
            cursor = conexao.cursor()
            # Query SQL para inserir os dados
            query = """
                INSERT INTO ocorrencias (aluno, data, descricao, tipo)
                VALUES (%s, %s, %s, %s)
            """
            # Converte a data de string para objeto date
            data_formatada = datetime.strptime(self.data, "%d/%m/%Y").date()
            # Executa a query com os valores
            cursor.execute(query, (
                self.aluno,
                data_formatada,
                self.get_descricao(),
                'simples'
            ))
            conexao.commit()             # Confirma a transação
            self.id = cursor.lastrowid   # Armazena o ID gerado
            print("✅ Ocorrência simples registrada no banco de dados.")
        except mysql.connector.Error as err:
            print(f"Erro ao registrar ocorrência: {err}")
        finally:
            cursor.close()  # Fecha o cursor mesmo em caso de erro

    # Exclui a ocorrência do banco de dados
    def excluir_no_banco(self, conexao):
        try:
            if self.id is None:
                print("Erro: ID da ocorrência não encontrado.")
                return
            cursor = conexao.cursor()
            # Query para deletar ocorrência com base no ID
            query = "DELETE FROM ocorrencias WHERE id = %s"
            cursor.execute(query, (self.id,))
            conexao.commit()
            print(f"✅ Ocorrência com ID {self.id} excluída com sucesso.")
        except mysql.connector.Error as err:
            print(f"Erro ao excluir ocorrência: {err}")
        finally:
            cursor.close()

# Classe que representa uma ocorrência grave (herda da classe OcorrenciaEscolar)
class OcorrenciaGrave(OcorrenciaEscolar):
    def __init__(self, aluno, data, descricao, nivel_gravidade):
        super().__init__(aluno, data, descricao)  # Chama o construtor da classe base
        self._nivel_gravidade = nivel_gravidade   # Nível de gravidade (privado)

    # Getter do nível de gravidade
    def get_nivel_gravidade(self):
        return self._nivel_gravidade

    # Setter do nível de gravidade
    def set_nivel_gravidade(self, novo_nivel):
        self._nivel_gravidade = novo_nivel
        print("Nível de gravidade atualizado com sucesso!")

    # Exibe os dados da ocorrência grave
    def exibir_ocorrencia(self):
        print("\n⚠️ ALERTA DE OCORRÊNCIA GRAVE ⚠️")
        print(f"Aluno: {self.aluno}")
        print(f"Data: {self.data}")
        print(f"Descrição: {self.get_descricao()}")
        print(f"Nível de Gravidade: {self._nivel_gravidade}")

    # Salva a ocorrência grave em duas tabelas: ocorrencias e ocorrencias_graves
    def salvar_no_banco(self, conexao):
        try:
            cursor = conexao.cursor()
            # Insere na tabela principal
            query_ocorrencia = """
                INSERT INTO ocorrencias (aluno, data, descricao, tipo)
                VALUES (%s, %s, %s, %s)
            """
            data_formatada = datetime.strptime(self.data, "%d/%m/%Y").date()
            cursor.execute(query_ocorrencia, (
                self.aluno,
                data_formatada,
                self.get_descricao(),
                'grave'
            ))
            conexao.commit()
            self.id = cursor.lastrowid

            # Insere o nível de gravidade na tabela específica
            query_grave = """
                INSERT INTO ocorrencias_graves (id, nivel_gravidade)
                VALUES (%s, %s)
            """
            cursor.execute(query_grave, (self.id, self._nivel_gravidade))
            conexao.commit()

            print("✅ Ocorrência grave registrada no banco de dados.")
        except mysql.connector.Error as err:
            print(f"Erro ao registrar ocorrência grave: {err}")
        finally:
            cursor.close()

# Função principal que executa o sistema de registro
def rodar_sistema():
    conexao = conectar_banco()  # Conecta ao banco de dados
    if not conexao:
        print("Não foi possível conectar ao banco de dados. Sistema encerrado.")
        return

    while True:
        # Interface interativa com o usuário
        print("\n=== Registro de Ocorrência ===")
        aluno = input("Nome do aluno: ").strip()
        data = input("Data da ocorrência (dd/mm/aaaa): ").strip()
        descricao = input("Descrição da ocorrência: ").strip()
        tipo = input("A ocorrência é grave? (s/n): ").strip().lower()

        # Cria objeto do tipo apropriado
        if tipo == 's':
            nivel = input("Nível de gravidade (Alta/Média/Baixa): ").strip().capitalize()
            ocorrencia = OcorrenciaGrave(aluno, data, descricao, nivel)
        else:
            ocorrencia = OcorrenciaEscolar(aluno, data, descricao)

        ocorrencia.exibir_ocorrencia()         # Exibe os dados
        ocorrencia.verificar_reincidencia()    # Verifica reincidência

        # Permite ao usuário atualizar a descrição
        if input("\nDeseja atualizar a descrição? (s/n): ").strip().lower() == 's':
            nova_desc = input("Digite a nova descrição: ")
            ocorrencia.atualizar_descricao(nova_desc)

        # Permite ao usuário alterar a data
        if input("Deseja alterar a data? (s/n): ").strip().lower() == 's':
            nova_data = input("Digite a nova data (dd/mm/aaaa): ")
            ocorrencia.alterar_data(nova_data)

        ocorrencia.exibir_ocorrencia()         # Exibe novamente após alterações
        ocorrencia.salvar_no_banco(conexao)    # Salva no banco de dados

        # Pergunta se deseja excluir a ocorrência recém-criada
        if input("\nDeseja excluir esta ocorrência? (s/n): ").strip().lower() == 's':
            ocorrencia.excluir_no_banco(conexao)

        # Pergunta se deseja registrar outra ocorrência
        if input("\nDeseja registrar outra ocorrência? (s/n): ").strip().lower() != 's':
            print("\nEncerrando o sistema de ocorrências.")
            break

    conexao.close()  # Fecha a conexão com o banco

# Inicia o sistema quando o script é executado
rodar_sistema()
# Out:
# Conexão com o banco de dados estabelecida com sucesso.
#
# === Registro de Ocorrência ===
# Nome do aluno:  gaby
# Data da ocorrência (dd/mm/aaaa):  23/05/2025
# Descrição da ocorrência:  dcsdcsw
# A ocorrência é grave? (s/n):  n
# Aluno: gaby
# Data: 23/05/2025
# Descrição: dcsdcsw
# Sem sinais de reincidência registrados.
# Deseja atualizar a descrição? (s/n):  n
# Deseja alterar a data? (s/n):
# Aluno: gaby
# Data: 23/05/2025
# Descrição: dcsdcsw
# ✅ Ocorrência simples registrada no banco de dados.
# Deseja excluir esta ocorrência? (s/n):  n
#
# Deseja registrar outra ocorrência? (s/n):  n
# Encerrando o sistema de ocorrências.
# Aluno: gabrielly
# Data: 27/05/2025
# Descrição: dsdfsd
# Sem sinais de reincidência registrados.
# Deseja atualizar a descrição? (s/n):  n
# Deseja alterar a data? (s/n):  n
# Aluno: gabrielly
# Data: 27/05/2025
# Descrição: dsdfsd
# ✅ Ocorrência simples registrada no banco de dados.
# Deseja excluir esta ocorrência? (s/n):  n
#
# ...
